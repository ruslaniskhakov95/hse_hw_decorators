# %% [markdown]
# # Домашнее задание: декораторы

# %% [markdown]
# ## Импорт библиотек, установка констант

# %%
import requests
import time
import re

from random import randint

# %%
BOOK_PATH = 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %% [markdown]
# ## Задание 1

# %%
def benchmark(func):
    """
    Декоратор, выводящий время, которое заняло выполнение декорируемой функции
    """

    def wrapper(*args, **kwargs):
        start = time.perf_counter()
        result = func(*args, **kwargs)
        end = time.perf_counter()
        print(f'Время выполнения функции {func.__name__}: {end - start}.')
        return result
    return wrapper

# %% [markdown]
# ## Задание 2

# %%
def logging(func):
    """
    Декоратор, который выводит параметры с которыми была вызвана функция
    """

    def wrapper(*args, **kwargs):
        result = func(*args, **kwargs)
        print(f'Функция вызвана с параметрами: {args}, {kwargs}')
        return result
    return wrapper

# %% [markdown]
# ## Задание 3

# %%
def counter(func):
    """
    Декоратор, считающий и выводящий количество вызовов декорируемой функции
    """

    def wrapper(*args, **kwargs):
        count = 0
        result = func(*args, **kwargs)
        count += 1
        print(f'Функция была вызвана: {count} раз')
        return result
    return wrapper

# %% [markdown]
# ## Задание 4

# %%
def memo(func):
  """
  Декоратор, запоминающий результаты исполнения функции func, чьи аргументы args должны быть хешируемыми
  """
  cache = {}

  def fmemo(*args):
    if args not in cache:
      cache[args] = func(*args)
    return cache[args]

  fmemo.cache = cache
  return fmemo

# %% [markdown]
# ## Тестирование

# %%
@counter
@logging
@benchmark
def word_count(word, url=BOOK_PATH):
    """
    Функция для посчета указанного слова на html-странице
    """

    # отправляем запрос в библиотеку Gutenberg и забираем текст
    raw = requests.get(url).text

    # заменяем в тексте все небуквенные символы на пробелы
    processed_book = re.sub('[\W]+' , ' ', raw).lower()

    # считаем
    cnt = len(re.findall(word.lower(), processed_book))

    return f"Cлово {word} встречается {cnt} раз"

print(word_count('whole'))
# Out:
# Время выполнения функции word_count: 1.9199478020000242.
# Функция вызвана с параметрами: ('whole',), {}
# Функция была вызвана: 1 раз
# Cлово whole встречается 176 раз

# %%
@benchmark
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
print(fib(9))
# Out:
# Время выполнения функции fib: 1.1610000001383014e-06.
# Время выполнения функции fib: 9.299999419454252e-07.
# Время выполнения функции fib: 6.24999984211172e-07.
# Время выполнения функции fib: 4.342799979895062e-05.
# Время выполнения функции fib: 0.00015370599999187107.
# Время выполнения функции fib: 4.1399994188395794e-07.
# Время выполнения функции fib: 5.539998255699174e-07.
# Время выполнения функции fib: 3.625600015766395e-05.
# Время выполнения функции fib: 4.890000582236098e-07.
# Время выполнения функции fib: 1.365999878544244e-06.
# Время выполнения функции fib: 1.1829999948531622e-06.
# Время выполнения функции fib: 0.00013304300000527292.
# Время выполнения функции fib: 0.0009009430000332941.
# Время выполнения функции fib: 0.000982788000101209.
# Время выполнения функции fib: 0.0011835590000828233.
# Время выполнения функции fib: 5.970000529487152e-07.
# Время выполнения функции fib: 6.299999313341687e-07.
# Время выполнения функции fib: 7.572599997729412e-05.
# Время выполнения функции fib: 5.780000265076524e-07.
# Время выполнения функции fib: 1.0339999789721332e-06.
# Время выполнения функции fib: 7.769999683659989e-07.
# Время выполнения функции fib: 9.071700014828821e-05.
# Время выполнения функции fib: 0.0038563959999464714.
# Время выполнения функции fib: 0.003977725000140708.
# Время выполнения функции fib: 4.6200011638575234e-07.
# Время выполнения функции fib: 5.160000000614673e-07.
# Время выполнения функции fib: 5.009999313188018e-07.
# Время выполнения функции fib: 3.4301000141567783e-05.
# Время выполнения функции fib: 7.016800009296276e-05.
# Время выполнения функции fib: 4.180001269560307e-07.
# Время выполнения функции fib: 4.379999154480174e-07.
# Время выполнения функции fib: 3.5182999909011414e-05.
# Время выполнения функции fib: 5.890001375519205e-07.
# Время выполнения функции fib: 9.410000529896934e-07.
# Время выполнения функции fib: 4.2800002120202407e-07.
# Время выполнения функции fib: 3.809300005741534e-05.
# Время выполнения функции fib: 7.42419999824051e-05.
# Время выполнения функции fib: 0.00014424400001189497.
# Время выполнения функции fib: 0.00024765000011939264.
# Время выполнения функции fib: 0.004260881000163863.
# Время выполнения функции fib: 0.005491880999898058.
# Время выполнения функции fib: 6.069999471947085e-07.
# Время выполнения функции fib: 4.73000000056345e-07.
# Время выполнения функции fib: 3.733499988811673e-05.
# Время выполнения функции fib: 4.679998255596729e-07.
# Время выполнения функции fib: 4.779999471793417e-07.
# Время выполнения функции fib: 4.61000126961153e-07.
# Время выполнения функции fib: 3.5818000014842255e-05.
# Время выполнения функции fib: 7.054200000311539e-05.
# Время выполнения функции fib: 0.00014247100011743896.
# Время выполнения функции fib: 5.15000010636868e-07.
# Время выполнения функции fib: 4.159999207331566e-07.
# Время выполнения функции fib: 5.140000212122686e-07.
# Время выполнения функции fib: 3.59000000571541e-05.
# Время выполнения функции fib: 7.073300002957694e-05.
# Время выполнения функции fib: 4.690000423579477e-07.
# Время выполнения функции fib: 4.949999947712058e-07.
# Время выполнения функции fib: 3.675099992506148e-05.
# Время выполнения функции fib: 5.060001058154739e-07.
# Время выполнения функции fib: 5.540000529435929e-07.
# Время выполнения функции fib: 4.90999809699133e-07.
# Время выполнения функции fib: 3.616200001488323e-05.
# Время выполнения функции fib: 7.106300017767353e-05.
# Время выполнения функции fib: 0.00014281399990068167.
# Время выполнения функции fib: 0.00026442500006851333.
# Время выполнения функции fib: 0.0004415799999151204.
# Время выполнения функции fib: 4.78999936603941e-07.
# Время выполнения функции fib: 5.839999630552484e-07.
# Время выполнения функции fib: 5.449999207485234e-07.
# Время выполнения функции fib: 3.596800002014788e-05.
# Время выполнения функции fib: 8.32129999253084e-05.
# Время выполнения функции fib: 6.19000047663576e-07.
# Время выполнения функции fib: 5.240001428319374e-07.
# Время выполнения функции fib: 3.655699993032613e-05.
# Время выполнения функции fib: 4.480000370676862e-07.
# Время выполнения функции fib: 4.869998520007357e-07.
# Время выполнения функции fib: 4.839998837269377e-07.
# Время выполнения функции fib: 3.734800020538387e-05.
# Время выполнения функции fib: 7.262000008267933e-05.
# Время выполнения функции fib: 0.00014474500017058745.
# Время выполнения функции fib: 0.0002634580000631104.
# Время выполнения функции fib: 3.969998942920938e-07.
# Время выполнения функции fib: 4.319999789004214e-07.
# Время выполнения функции fib: 3.4574999972392106e-05.
# Время выполнения функции fib: 4.399998942972161e-07.
# Время выполнения функции fib: 7.539999842265388e-07.
# Время выполнения функции fib: 6.570001005457016e-07.
# Время выполнения функции fib: 5.628900021292793e-05.
# Время выполнения функции fib: 0.0012063879999004712.
# Время выполнения функции fib: 0.0012747539999509172.
# Время выполнения функции fib: 4.4100011109549087e-07.
# Время выполнения функции fib: 4.010000793641666e-07.
# Время выполнения функции fib: 2.0390000372572104e-06.
# Время выполнения функции fib: 0.00020168000014564313.
# Время выполнения функции fib: 0.0002419329998701869.
# Время выполнения функции fib: 5.099998361401958e-07.
# Время выполнения функции fib: 6.259999736357713e-07.
# Время выполнения функции fib: 4.358699993645132e-05.
# Время выполнения функции fib: 5.950000740995165e-07.
# Время выполнения функции fib: 1.26400004774041e-06.
# Время выполнения функции fib: 1.8480000107956585e-06.
# Время выполнения функции fib: 0.00314564700011033.
# Время выполнения функции fib: 0.0031892210001842614.
# Время выполнения функции fib: 0.0032708219998767163.
# Время выполнения функции fib: 0.0035514819999207248.
# Время выполнения функции fib: 0.0048602419999497215.
# Время выполнения функции fib: 0.005157076999921628.
# Время выполнения функции fib: 0.005633063000004768.
# Время выполнения функции fib: 0.011162881000018388.
# 34

# %%
@benchmark
@memo
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
print(fib(9))
# Out:
# Время выполнения функции fmemo: 2.5800000003073364e-06.
# Время выполнения функции fmemo: 3.524000021570828e-06.
# Время выполнения функции fmemo: 1.8609998733154498e-06.
# Время выполнения функции fmemo: 0.000154793000092468.
# Время выполнения функции fmemo: 0.0024206260000028124.
# Время выполнения функции fmemo: 9.079999472305644e-07.
# Время выполнения функции fmemo: 1.0660000953066628e-06.
# Время выполнения функции fmemo: 5.1980000080220634e-05.
# Время выполнения функции fmemo: 0.0025235929999780637.
# Время выполнения функции fmemo: 1.0099997780343983e-06.
# Время выполнения функции fmemo: 1.1100000847363845e-06.
# Время выполнения функции fmemo: 5.4909000027691945e-05.
# Время выполнения функции fmemo: 0.0026324539999222907.
# Время выполнения функции fmemo: 9.140001111518359e-07.
# Время выполнения функции fmemo: 1.2909999895782676e-06.
# Время выполнения функции fmemo: 7.099300000845687e-05.
# Время выполнения функции fmemo: 0.002786007000167956.
# 34
